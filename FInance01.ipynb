# %%
#libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Simple Interest

# %%
PV = 1000
i = 0.10 #10% per annum
n = 100 # years
#FV = ?

FVS = {'Present Value':[], 'Interest % per annum':[], 'Year':[], 'Future Value':[]}

for x in range(0,n+1):
    value = PV*(1+i*x)
    y = round(value, 2)
    FVS['Present Value'].append(PV)
    FVS['Interest % per annum'].append(i*100)
    FVS['Year'].append(x)
    FVS['Future Value'].append(y)
SimpleInterest = pd.DataFrame(data=FVS, index=None)
print("Simple Interest Table")
SimpleInterest
# Out:
# Simple Interest Table
#      Present Value  Interest % per annum  Year  Future Value
# 0             1000                  10.0     0        1000.0
# 1             1000                  10.0     1        1100.0
# 2             1000                  10.0     2        1200.0
# 3             1000                  10.0     3        1300.0
# 4             1000                  10.0     4        1400.0
# ..             ...                   ...   ...           ...
# 96            1000                  10.0    96       10600.0
# 97            1000                  10.0    97       10700.0
# 98            1000                  10.0    98       10800.0
# 99            1000                  10.0    99       10900.0
# 100           1000                  10.0   100       11000.0
#
# [101 rows x 4 columns]

# %%
yaxis = SimpleInterest['Future Value']
xaxis = SimpleInterest['Year']
fig, ax = plt.subplots(figsize=(12,8), constrained_layout=True)
ax.plot(xaxis, yaxis)
ax.set_xlabel('Years')
ax.set_ylabel('Future Value')
ax.set_title('Simple Interest')
fig.set_facecolor('lightsteelblue')

# %% [markdown]
# # Compounding Interest

# %%
PV = 1000
i = 0.10 #10% per annum
n = 100 # years
#FV = ?

FVS2 = {'Present Value':[], 'Interest % per annum':[], 'Year':[], 'Future Value':[]}

for x in range(0,n+1):
    value2 = PV*(1+i)**x
    z = round(value2, 2)
    FVS2['Present Value'].append(PV)
    FVS2['Interest % per annum'].append(i*100)
    FVS2['Year'].append(x)
    FVS2['Future Value'].append(z)
CompoundingInterest = pd.DataFrame(data=FVS2, index=None)
print("Compounding Interest Table")
CompoundingInterest
# Out:
# Compounding Interest Table
#      Present Value  Interest % per annum  Year  Future Value
# 0             1000                  10.0     0       1000.00
# 1             1000                  10.0     1       1100.00
# 2             1000                  10.0     2       1210.00
# 3             1000                  10.0     3       1331.00
# 4             1000                  10.0     4       1464.10
# ..             ...                   ...   ...           ...
# 96            1000                  10.0    96    9412343.65
# 97            1000                  10.0    97   10353578.02
# 98            1000                  10.0    98   11388935.82
# 99            1000                  10.0    99   12527829.40
# 100           1000                  10.0   100   13780612.34
#
# [101 rows x 4 columns]

# %%
yaxis2 = CompoundingInterest['Future Value']
xaxis2 = CompoundingInterest['Year']
fig, ax = plt.subplots(figsize=(12,8), constrained_layout=True)
ax.plot(xaxis2, yaxis2)
ax.set_xlabel('Years')
ax.set_ylabel('Future Value')
ax.set_title('Compounding Interest')
fig.set_facecolor('lightsteelblue')
